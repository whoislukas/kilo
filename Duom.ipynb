# %%
from csv import reader
open_data = open("data5.csv", encoding="utf-8") #Pakeisti pavadinima i failo pavadinima formatas "data.csv"
read_data = reader(open_data)
data_list = list(read_data)
sku_list = []
date_list = []
item_quantity_list = []
product_quantity = {}
cb_list = ["ColonBroom", "CB-colonbroom1", "CB-colonbroom3", "CB-colonbroom6", "CB-precolonbroom6"]
kc_list = ["KC-keto_fuel_vanilla", "KC-keto_fuel_chocolate", "KC-keto_fuel_vanilla, KC-keto_fuel_chocolate"]
kc_bhb_list = ["KC-bhb_peach, KC-bhb_raspberry", "KC-bhb_raspberry", "KC-bhb_peach"]
kc_ele_list = ["KC-hydration_recovery_bag-1","KC-hydration_recovery_bag-3","KC-hydration_recovery_bag-6"]
df_kf_list = ["DF-KF Chocolate", "DF-KF Vanilla, DF-KF Chocolate", "DF-KF Vanilla", "DF-KF Chocolate, DF-KF Vanilla"]
df_bhb_list = ["DF-BHB Peach, DF-BHB Raspberry", "DF-BHB Raspberry, DF-BHB Peach","DF-BHB Raspberry","DF-BHB Peach"]
df_box_list = ["DF-Powder_box_1", "DF-Powder_box_3", "DF-Powder_box_6"]
df_gum_list = ["DF-Gummies_3", "DF-Gummies_5", "DF-Gummies_1"]
df_bundle = ['DF-TESTING-BHB Peach, DF-TESTING-BHB Raspberry, DF-TESTING-Powder_box_1, DF-TESTING-Gummies_1',"DF-BHB Peach, DF-Powder_box_1, DF-Gummies_1", "DF-BHB Peach, DF-BHB Raspberry, DF-Poweder_box_1", "DF-Gummies_1","DF-BHB Raspberry, DF-BHB Peach, DF-Powder_box_1, DF-Gummies_1", "DF-BHB Raspberry, DF-Powder_box_1, DF-Gummies_1", "DF-BHB Peach, DF-BHB Raspberry, DF-Powder_box_1, DF-Gummies_1"]
md_box_list = ["MD-MD_weight_loss_fuel"]
rd_ele_list = ["RD-hydration_recovery_bag_1"]
rd_burn_list = ["RD-fat_burner_bottle_x2_month", "RD-fat_burner_bottle_x6_3months", "RD-fat_burner_bottle_x4_2months"]
jg_ele_list = ["S-JGO-Hydration_recovery_bag_6", "S-JGO-Hydration_recovery_bag_1", "S-JGO-Hydration_recovery_bag_3", "S-JGO-TESTING-Hydration_recovery_bag_6"]
jg_burn_list = ["S-JGO-fat_burner_bottle_1", "S-JGO-fat_burner_bottle_2", "S-JGO-fat_burner_bottle_3", "S-JGO-TESTING-fat_burner_bottle_3", "S-JGO-TESTING-fat_burner_bottle_1","S-JGO-TESTING-fat_burner_bottle_2", "S-JGO-fat_burner_bottle_x2_month"]
mfc_box_list = ["MFC-Powder_box_1", "MFC-Powder_box_3", "MFC-TESTING-Powder_box_1"]
mfc_kf_list = ["MFC-KF Chocolate, MFC-KF Vanilla","MFC-KF Vanilla","MFC-KF Chocolate", "MFC-KF Vanilla, MFC-KF Chocolate", "MFC-TESTING-KF Vanilla"]
mfc_bhb_list = ["MFC-BHB Peach, MFC-BHB Raspberry", "MFC-BHB Peach", "MFC-BHB Raspberry", "MFC-BHB Raspberry, MFC-BHB Peach"]
quiz_box_list = ["S-DF-df-box-x3", "S-DF-df-box-x1","S-DF-df-box-x6"]
quiz_gum_list = ["S-DF-df-box-x6-gummies-x6", "S-DF-df-box-x1-gummies-x1","S-DF-df-box-x3-gummies-x3","S-DF-df-box-x2-gummies-x2","S-DF-df-box-x1-gummies-x2", "S-DF-df-box-x2-gummies-x4", "S-DF-df-box-x4-gummies-x4", "S-DF-df-box-x4-gummies-x6"]
shop_list = []
nixwhite_list = ["NixWhite","NIX-kit_whitening_1_gel_3"]
nix_re_list = ["NIX-nix-gel-upsell-3", "NIX-nix-gel-upsell-6"]
sku_full_list = ["ColonBroom", "CB-colonbroom1", "CB-colonbroom3", "CB-colonbroom6", "CB-precolonbroom6","KC-keto_fuel_vanilla", "KC-keto_fuel_chocolate", "KC-keto_fuel_vanilla, KC-keto_fuel_chocolate","KC-bhb_peach, KC-bhb_raspberry", "KC-bhb_raspberry", "KC-bhb_peach","KC-hydration_recovery_bag-1","DF-KF Chocolate", "DF-KF Vanilla, DF-KF Chocolate", "DF-KF Vanilla", "DF-KF Chocolate, DF-KF Vanilla","DF-BHB Peach, DF-BHB Raspberry", "DF-BHB Raspberry, DF-BHB Peach","DF-BHB Raspberry","DF-BHB Peach","DF-Powder_box_1", "DF-Powder_box_3", "DF-Powder_box_6","DF-Gummies_3", "DF-Gummies_5", "DF-Gummies_1","MD-MD_weight_loss_fuel","RD-hydration_recovery_bag_1","RD-fat_burner_bottle_x2_month", "RD-fat_burner_bottle_x6_3months","S-JGO-Hydration_recovery_bag_6", "S-JGO-Hydration_recovery_bag_1", "S-JGO-Hydration_recovery_bag_3", "S-JGO-TESTING-Hydration_recovery_bag_6","S-JGO-fat_burner_bottle_1", "S-JGO-fat_burner_bottle_2", "S-JGO-fat_burner_bottle_3", "S-JGO-TESTING-fat_burner_bottle_3", "S-JGO-TESTING-fat_burner_bottle_1","S-JGO-TESTING-fat_burner_bottle_2","MFC-Powder_box_1", "MFC-Powder_box_3","MFC-KF Chocolate, MFC-KF Vanilla","MFC-KF Vanilla","MFC-KF Chocolate", "MFC-KF Vanilla, MFC-KF Chocolate","MFC-BHB Peach, MFC-BHB Raspberry", "MFC-BHB Peach", "MFC-BHB Raspberry", "MFC-BHB Raspberry, MFC-BHB Peach","S-DF-df-box-x3", "S-DF-df-box-x1","S-DF-df-box-x6","S-DF-df-box-x6-gummies-x6", "S-DF-df-box-x1-gummies-x1","S-DF-df-box-x3-gummies-x3","S-DF-df-box-x2-gummies-x2","S-DF-df-box-x1-gummies-x2", "S-DF-df-box-x2-gummies-x4", "S-DF-df-box-x4-gummies-x4", "S-DF-df-box-x4-gummies-x6","NixWhite","NIX-kit_whitening_1_gel_3","NIX-nix-gel-upsell-3", "NIX-nix-gel-upsell-6", "RD-fat_burner_bottle_x4_2months", "MFC-TESTING-Powder_box_1", "DF-TESTING-BHB Peach, DF-TESTING-BHB Raspberry, DF-TESTING-Powder_box_1, DF-TESTING-Gummies_1", "MFC-TESTING-KF Vanilla", "DF-BHB Peach, DF-Powder_box_1, DF-Gummies_1","S-JGO-fat_burner_bottle_x2_month", "DF-BHB Peach, DF-BHB Raspberry, DF-Poweder_box_1", "DF-Gummies_1","DF-BHB Raspberry, DF-BHB Peach, DF-Powder_box_1, DF-Gummies_1", "DF-BHB Raspberry, DF-Powder_box_1, DF-Gummies_1", "DF-BHB Peach, DF-BHB Raspberry, DF-Powder_box_1, DF-Gummies_1"]

date_lst = ["06/12/2021"] #Ivesti data ranka formatas "06/01/2021"

sku_date_list = []            
product_quantity = {}
full_sku = []
product_quantity_1 = {}

def date_check(dat, product):
    
    for row in data_list[1:]:
        sku = row[19]
        item_quantity = row[20]
        date = row[1]
        if dat == date and product == sku:
            if sku in product_quantity:      
                product_quantity[sku] += int(item_quantity)
            else:
                product_quantity[sku] = int(item_quantity)
                                
def sku_count(product_list):
    for lst in product_list:
        for dat in date_lst:
            date_check(dat, lst)
    print(product_quantity)
    product_quantity.clear()

def date_all_sku(datt):
    for row in data_list[1:]:
        date = row[1]
        sku = row[19]
        if datt == date:
            full_sku.append(row[19])
        else:
            continue

date_all_sku("06/12/2021") #IVESTI DATA RANKINIU BUDU

sku_count(df_bhb_list)
sku_count(df_box_list)
sku_count(df_kf_list)
sku_count(df_gum_list)
sku_count(df_bundle)

sku_count(kc_list)
sku_count(kc_bhb_list)
sku_count(kc_ele_list)

sku_count(md_box_list)

sku_count(rd_ele_list)
sku_count(rd_burn_list)

sku_count(jg_ele_list)
sku_count(jg_burn_list)

sku_count(mfc_box_list)
sku_count(mfc_kf_list)
sku_count(mfc_bhb_list)


sku_count(quiz_box_list)
sku_count(quiz_gum_list)

sku_count(cb_list)

#shopify prideti

sku_count(nixwhite_list)
sku_count(nix_re_list)



for row in full_sku:
    if row in sku_full_list:
        continue
    else:
        sku_date_list.append(row)
        
def date_check_1(dat, product):
    
    for row in data_list[1:]:
        sku = row[19]
        item_quantity = row[20]
        date = row[1]
        merge = row[5]
        if dat == date and product == sku and "Merged:" not in merge:
            if sku in product_quantity:      
                product_quantity_1[sku] += int(item_quantity)
            else:
                product_quantity_1[sku] = int(item_quantity)
 
def sku_count_1(product_list):
    for lst in product_list:
        for dat in date_lst:
            date_check_1(dat, lst)
    print(product_quantity_1)
    product_quantity.clear()

sku_count_1(sku_date_list)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
